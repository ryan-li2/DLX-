# %%
import numpy as np
import pandas as pd
import timeit
import copy
import time
import itertools
import os
from joblib import Parallel, delayed
import json
import networkx as nx
from functions import *

percentiles = [0.01,0.05, 0.25, 0.50, 0.75, 0.95, 0.99]#Backtracking depth percentile based on the beam load distribution
thread = 10# using 10 threads
dfs_best_of_fastest = []
dfs_fastest_of_best = []
N_max=60
n_colour=4
R=range(n_colour)
Gurobi_SOL=pd.DataFrame(columns=['Instance','User','Simulation','Solver','Computation Time(s)','Total Allocated Demand'])
OR_TOOLS_SOL=pd.DataFrame(columns=['Instance','User','Simulation','Solver','Computation Time(s)','Total Allocated Demand'])
for z in [4]:#4:Realistic, 8:Random, 12:Clustered
    for INS in [500]:#Number of users
        Data=pd.read_excel('Data/User Data/Instance_'+str(z)+'.xlsx')
        data=Data.iloc[:INS].copy()
        for h in range(20): #problems     
            beams=pd.read_csv('Data/Beam Candidate/Beams_'+str(z)+'_'+str(INS)+'_60_4_sample'+str(h)+'.csv',index_col=0)
            f = open('Data/Beam Candidate/Allocate_'+str(z)+'_'+str(INS)+'_60_4_sample'+str(h)+'.txt','r')
            allocate_data=f.read()
            f.close()
            allocate=eval(allocate_data)
            pairs_file = os.path.join('Data/Beam Candidate/', 'Pairs_'+str(z)+'_'+str(INS)+'_sample'+str(h)+'.json')
            with open(pairs_file, 'r') as f:
                pairs = json.load(f)

            rows_color, orig_row, pos, D_color,u,adj,cum_demands,back=input_structure(beams,allocate,data,pairs,percentiles)

            Cons=incidence_transpose_fast(rows_color)

            t_start = timeit.default_timer()

            guro_integer,guro_obj,guro_solver_time=gurobi_SPK(rows_color,D_color,N_max,Cons)

            t_end = timeit.default_timer()

            Gurobi_SOL.loc[len(Gurobi_SOL)]=[z,INS,h,'Gurobi',t_end-t_start,guro_obj]

            t_start = timeit.default_timer()

            or_integer,or_obj,or_solver_time=cpsat_SPK(rows_color,D_color,N_max,Cons, log=True)

            t_end = timeit.default_timer()

            OR_TOOLS_SOL.loc[len(OR_TOOLS_SOL)]=[z,INS,h,'OR_Tools',t_end-t_start,or_obj]

            t_start = timeit.default_timer()

            LB, greedy_sol= greedy_solution(rows_color, orig_row, pos, D_color, N_max, adj)

            t_end = timeit.default_timer()
            t=t_end-t_start

            #Testing on various backtracking depths
            thread_time={p:100 for p in range(7)}
            thread_result={p:100 for p in range(7)}

            for run in range(3):
                for p,node in enumerate(back):

                    best=LB
  
                    t_start2 = timeit.default_timer()

                    solver = DLX(u + 1,rows_color,orig_row,D_color,LB,N_max,node)

                    if node>0:
                        for integer, obj in solver.search_range():
                            if obj > best:
                                best = obj
                                optimal = integer.copy()
                    t2 = timeit.default_timer() - t_start2
                    D_time = t+t2
                    if D_time<thread_time[p]:
                        thread_time[p]=D_time
                    thread_result[p] = best
                    

            results = Parallel(n_jobs=10,backend="loky")(delayed(run_single_i)(i,rows_color,D_color,orig_row,back,LB,N_max,u,t,thread_time,thread_result)
                               for i in range(thread))    

            
            best_of_fastest, fastest_of_best = cumulative_analysis(thread, results, range(len(back)))
            # ---------- Best of Fastest ----------
            dfs_best_of_fastest.append({
                "Instance": z,
                "User": INS,
                "Simulation": h,
                "Backtracking based on percentiles": best_of_fastest["p"],
                "Total Allocated Demand": best_of_fastest["value"],
                "Computation Time(s)": best_of_fastest["time"],
            })

            # ---------- Fastest of Best ----------
            dfs_fastest_of_best.append({
                "Instance": z,
                "User": INS,
                "Simulation": h,
                "Backtracking percentiles idx": fastest_of_best["p"],
                "Total Allocated Demand": fastest_of_best["value"],
                "Computation Time(s)": fastest_of_best["time"],               
            })

            print(f"Completed: z={z}, INS={INS}, simulation={h}")


# ---------------- Convert to DataFrames ----------------

DLX_v1 = pd.DataFrame(dfs_fastest_of_best)
DLX_v2 = pd.DataFrame(dfs_best_of_fastest)
DLX_v1.to_csv('DLXv1_results.csv')
DLX_v2.to_csv('DLXv2_results.csv')
Gurobi_SOL.to_csv('Gurobi_results.csv')
OR_TOOLS_SOL.to_csv('OR_TOOLS_results.csv')
# Out:
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1853 rows, 1188 columns and 14996 nonzeros
# Model fingerprint: 0x46f38d97
# Variable types: 0 continuous, 1188 integer (1188 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 950350.00000
# Presolve removed 813 rows and 106 columns
# Presolve time: 0.03s
# Presolved: 1040 rows, 1082 columns, 13305 nonzeros
# Found heuristic solution: objective 950350.00000
# Variable types: 0 continuous, 1082 integer (1081 binary)
#
# Root relaxation: objective 9.796917e+05, 325 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 979691.667    0   11 950350.000 979691.667  3.09%     -    0s
# H    0     0                    978500.00000 979691.667  0.12%     -    0s
# H    0     0                    979500.00000 979691.667  0.02%     -    0s
#
# Explored 1 nodes (497 simplex iterations) in 0.06 seconds (0.08 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 4: 979500 978500 950350 950350
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.795000000000e+05, best bound 9.795000000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=0
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2117 rows, 1404 columns and 24068 nonzeros
# Model fingerprint: 0x082356a1
# Variable types: 0 continuous, 1404 integer (1404 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 953075.00000
# Presolve removed 771 rows and 150 columns
# Presolve time: 0.05s
# Presolved: 1346 rows, 1254 columns, 21779 nonzeros
# Found heuristic solution: objective 953075.00000
# Variable types: 0 continuous, 1254 integer (1252 binary)
#
# Root relaxation: objective 9.842250e+05, 496 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 984225.000    0    6 953075.000 984225.000  3.27%     -    0s
# H    0     0                    983450.00000 984225.000  0.08%     -    0s
#      0     0 984225.000    0    6 983450.000 984225.000  0.08%     -    0s
#
# Explored 1 nodes (497 simplex iterations) in 0.10 seconds (0.14 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 983450 953075 953075
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.834500000000e+05, best bound 9.834500000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1713 rows, 1220 columns and 15936 nonzeros
# Model fingerprint: 0xe8b8b472
# Variable types: 0 continuous, 1220 integer (1220 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 965875.00000
# Presolve removed 680 rows and 131 columns
# Presolve time: 0.04s
# Presolved: 1033 rows, 1089 columns, 14116 nonzeros
# Found heuristic solution: objective 965875.00000
# Variable types: 0 continuous, 1089 integer (1088 binary)
#
# Root relaxation: objective 9.822779e+05, 402 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 982277.941    0   31 965875.000 982277.941  1.70%     -    0s
# H    0     0                    977850.00000 982277.941  0.45%     -    0s
# H    0     0                    978125.00000 982277.941  0.42%     -    0s
# *    0     0               0    981100.00000 981100.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 5
#   Implied bound: 1
#   Clique: 1
#   Zero half: 4
#
# Explored 1 nodes (841 simplex iterations) in 0.08 seconds (0.11 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 5: 981100 978125 977850 ... 965875
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.811000000000e+05, best bound 9.811000000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=2
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1877 rows, 1244 columns and 18004 nonzeros
# Model fingerprint: 0x8c90f2a8
# Variable types: 0 continuous, 1244 integer (1244 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 946375.00000
# Presolve removed 718 rows and 145 columns
# Presolve time: 0.04s
# Presolved: 1159 rows, 1099 columns, 16587 nonzeros
# Found heuristic solution: objective 946375.00000
# Variable types: 0 continuous, 1099 integer (1097 binary)
#
# Root relaxation: objective 9.802750e+05, 316 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    980275.00000 980275.000  0.00%     -    0s
#
# Explored 1 nodes (316 simplex iterations) in 0.10 seconds (0.09 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 980275 946375 946375
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.802750000000e+05, best bound 9.802750000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=3
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1681 rows, 1164 columns and 14600 nonzeros
# Model fingerprint: 0x1cdd9add
# Variable types: 0 continuous, 1164 integer (1164 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 938600.00000
# Presolve removed 637 rows and 104 columns
# Presolve time: 0.03s
# Presolved: 1044 rows, 1060 columns, 13784 nonzeros
# Found heuristic solution: objective 938600.00000
# Variable types: 0 continuous, 1060 integer (1058 binary)
#
# Root relaxation: objective 9.801000e+05, 384 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 980100.000    0    4 938600.000 980100.000  4.42%     -    0s
# H    0     0                    980100.00000 980100.000  0.00%     -    0s
#      0     0 980100.000    0    4 980100.000 980100.000  0.00%     -    0s
#
# Explored 1 nodes (384 simplex iterations) in 0.05 seconds (0.07 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 980100 938600 938600
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.801000000000e+05, best bound 9.801000000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=4
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1625 rows, 1108 columns and 14364 nonzeros
# Model fingerprint: 0xbbe71dff
# Variable types: 0 continuous, 1108 integer (1108 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 954025.00000
# Presolve removed 624 rows and 119 columns
# Presolve time: 0.04s
# Presolved: 1001 rows, 989 columns, 13454 nonzeros
# Found heuristic solution: objective 954025.00000
# Variable types: 0 continuous, 989 integer (988 binary)
#
# Root relaxation: objective 9.777000e+05, 329 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 977700.000    0   18 954025.000 977700.000  2.48%     -    0s
# H    0     0                    976925.00000 977700.000  0.08%     -    0s
#      0     0     cutoff    0      976925.000 976925.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Clique: 3
#   Zero half: 5
#
# Explored 1 nodes (647 simplex iterations) in 0.07 seconds (0.10 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 976925 954025 954025
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.769250000000e+05, best bound 9.769250000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=5
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1961 rows, 1300 columns and 19308 nonzeros
# Model fingerprint: 0xe601b139
# Variable types: 0 continuous, 1300 integer (1300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 959350.00000
# Presolve removed 694 rows and 146 columns
# Presolve time: 0.04s
# Presolved: 1267 rows, 1154 columns, 19011 nonzeros
# Found heuristic solution: objective 959350.00000
# Variable types: 0 continuous, 1154 integer (1152 binary)
#
# Root relaxation: objective 9.836500e+05, 399 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 983650.000    0    8 959350.000 983650.000  2.53%     -    0s
# H    0     0                    982775.00000 983650.000  0.09%     -    0s
#      0     0     cutoff    0      982775.000 982775.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Clique: 1
#   MIR: 1
#   Zero half: 3
#
# Explored 1 nodes (678 simplex iterations) in 0.08 seconds (0.12 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 982775 959350 959350
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.827750000000e+05, best bound 9.827750000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=6
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2017 rows, 1228 columns and 20752 nonzeros
# Model fingerprint: 0x11d06e4a
# Variable types: 0 continuous, 1228 integer (1228 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 956325.00000
# Presolve removed 710 rows and 144 columns
# Presolve time: 0.05s
# Presolved: 1307 rows, 1084 columns, 19433 nonzeros
# Found heuristic solution: objective 956325.00000
# Variable types: 0 continuous, 1084 integer (1083 binary)
#
# Root relaxation: objective 9.828250e+05, 341 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 982825.000    0    4 956325.000 982825.000  2.77%     -    0s
# H    0     0                    982050.00000 982825.000  0.08%     -    0s
#      0     0 infeasible    0      982050.000 982050.000  0.00%     -    0s
#
# Explored 1 nodes (344 simplex iterations) in 0.08 seconds (0.11 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 982050 956325 956325
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.820500000000e+05, best bound 9.820500000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=7
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1845 rows, 1184 columns and 15456 nonzeros
# Model fingerprint: 0x7347b334
# Variable types: 0 continuous, 1184 integer (1184 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 959975.00000
# Presolve removed 810 rows and 161 columns
# Presolve time: 0.04s
# Presolved: 1035 rows, 1023 columns, 13867 nonzeros
# Found heuristic solution: objective 959975.00000
# Variable types: 0 continuous, 1023 integer (1021 binary)
#
# Root relaxation: objective 9.801529e+05, 360 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 980152.941    0   15 959975.000 980152.941  2.10%     -    0s
# H    0     0                    978950.00000 980152.941  0.12%     -    0s
# H    0     0                    979950.00000 980152.941  0.02%     -    0s
#      0     0          -    0      979950.000 980033.333  0.01%     -    0s
#
# Cutting planes:
#   Clique: 1
#   Zero half: 1
#
# Explored 1 nodes (542 simplex iterations) in 0.07 seconds (0.10 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 4: 979950 978950 959975 959975
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.799500000000e+05, best bound 9.800250000000e+05, gap 0.0077%
# Completed: z=4, INS=500, simulation=8
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1857 rows, 1156 columns and 16588 nonzeros
# Model fingerprint: 0xf0659d53
# Variable types: 0 continuous, 1156 integer (1156 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 960150.00000
# Presolve removed 622 rows and 126 columns
# Presolve time: 0.04s
# Presolved: 1235 rows, 1030 columns, 16367 nonzeros
# Found heuristic solution: objective 960150.00000
# Variable types: 0 continuous, 1030 integer (1029 binary)
#
# Root relaxation: objective 9.798092e+05, 329 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 979809.191    0   32 960150.000 979809.191  2.05%     -    0s
# H    0     0                    978075.00000 979809.191  0.18%     -    0s
#      0     0 978291.667    0   28 978075.000 978291.667  0.02%     -    0s
#      0     0     cutoff    0      978075.000 978075.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 6
#   Clique: 3
#   MIR: 1
#   Zero half: 2
#
# Explored 1 nodes (635 simplex iterations) in 0.08 seconds (0.12 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 978075 960150 960150
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.780750000000e+05, best bound 9.780750000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=9
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 2217 rows, 1376 columns and 22844 nonzeros
# Model fingerprint: 0x180d068d
# Variable types: 0 continuous, 1376 integer (1376 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 961850.00000
# Presolve removed 947 rows and 138 columns
# Presolve time: 0.05s
# Presolved: 1270 rows, 1238 columns, 19305 nonzeros
# Found heuristic solution: objective 964350.00000
# Variable types: 0 continuous, 1238 integer (1236 binary)
#
# Root relaxation: objective 9.815529e+05, 623 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 981552.941    0   22 964350.000 981552.941  1.78%     -    0s
# H    0     0                    978225.00000 981552.941  0.34%     -    0s
# H    0     0                    979900.00000 981552.941  0.17%     -    0s
# H    0     0                    981125.00000 981552.941  0.04%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Clique: 2
#   MIR: 2
#
# Explored 1 nodes (985 simplex iterations) in 0.10 seconds (0.15 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 5: 981125 979900 978225 ... 961850
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.811250000000e+05, best bound 9.811250000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=10
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1797 rows, 1260 columns and 17428 nonzeros
# Model fingerprint: 0xce364a24
# Variable types: 0 continuous, 1260 integer (1260 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 959200.00000
# Presolve removed 598 rows and 131 columns
# Presolve time: 0.04s
# Presolved: 1199 rows, 1129 columns, 17265 nonzeros
# Found heuristic solution: objective 959200.00000
# Variable types: 0 continuous, 1129 integer (1128 binary)
#
# Root relaxation: objective 9.836000e+05, 387 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 983600.000    0    4 959200.000 983600.000  2.54%     -    0s
# H    0     0                    982825.00000 983600.000  0.08%     -    0s
#
# Explored 1 nodes (387 simplex iterations) in 0.07 seconds (0.10 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 982825 959200 959200
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.828250000000e+05, best bound 9.828250000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=11
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1777 rows, 1204 columns and 15524 nonzeros
# Model fingerprint: 0x4540e77c
# Variable types: 0 continuous, 1204 integer (1204 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 969100.00000
# Presolve removed 697 rows and 134 columns
# Presolve time: 0.04s
# Presolved: 1080 rows, 1070 columns, 14166 nonzeros
# Found heuristic solution: objective 969100.00000
# Variable types: 0 continuous, 1070 integer (1067 binary)
#
# Root relaxation: objective 9.813625e+05, 356 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 981362.500    0   10 969100.000 981362.500  1.27%     -    0s
# H    0     0                    981050.00000 981362.500  0.03%     -    0s
#      0     0 infeasible    0      981050.000 981050.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 2
#
# Explored 1 nodes (622 simplex iterations) in 0.07 seconds (0.10 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 981050 969100 969100
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.810500000000e+05, best bound 9.810500000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=12
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1485 rows, 1164 columns and 12444 nonzeros
# Model fingerprint: 0x7cb7e239
# Variable types: 0 continuous, 1164 integer (1164 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 959750.00000
# Presolve removed 577 rows and 139 columns
# Presolve time: 0.03s
# Presolved: 908 rows, 1025 columns, 11829 nonzeros
# Found heuristic solution: objective 959750.00000
# Variable types: 0 continuous, 1025 integer (1024 binary)
#
# Root relaxation: objective 9.793750e+05, 317 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 979375.000    0    8 959750.000 979375.000  2.04%     -    0s
# H    0     0                    976950.00000 979375.000  0.25%     -    0s
# H    0     0                    978500.00000 979375.000  0.09%     -    0s
#
# Cutting planes:
#   Clique: 1
#   Zero half: 2
#
# Explored 1 nodes (652 simplex iterations) in 0.06 seconds (0.07 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 4: 978500 976950 959750 959750
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.785000000000e+05, best bound 9.785750000000e+05, gap 0.0077%
# Completed: z=4, INS=500, simulation=13
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1385 rows, 1040 columns and 9960 nonzeros
# Model fingerprint: 0xf62a17ef
# Variable types: 0 continuous, 1040 integer (1040 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 947075.00000
# Presolve removed 590 rows and 151 columns
# Presolve time: 0.03s
# Presolved: 795 rows, 889 columns, 9485 nonzeros
# Found heuristic solution: objective 947075.00000
# Variable types: 0 continuous, 889 integer (887 binary)
#
# Root relaxation: objective 9.787434e+05, 268 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 978743.382    0   13 947075.000 978743.382  3.34%     -    0s
# H    0     0                    976550.00000 978743.382  0.22%     -    0s
# H    0     0                    977550.00000 978743.382  0.12%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Clique: 2
#   Zero half: 1
#
# Explored 1 nodes (418 simplex iterations) in 0.05 seconds (0.06 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 4: 977550 976550 947075 947075
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.775500000000e+05, best bound 9.775500000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=14
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1593 rows, 1112 columns and 11972 nonzeros
# Model fingerprint: 0x2cb020a3
# Variable types: 0 continuous, 1112 integer (1112 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 955175.00000
# Presolve removed 601 rows and 123 columns
# Presolve time: 0.03s
# Presolved: 992 rows, 989 columns, 12194 nonzeros
# Found heuristic solution: objective 955175.00000
# Variable types: 0 continuous, 989 integer (987 binary)
#
# Root relaxation: objective 9.829279e+05, 307 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 982927.941    0   20 955175.000 982927.941  2.91%     -    0s
# H    0     0                    980400.00000 982927.941  0.26%     -    0s
# H    0     0                    981000.00000 982927.941  0.20%     -    0s
# *    0     0               0    981950.00000 981950.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Clique: 2
#   MIR: 2
#   Zero half: 2
#
# Explored 1 nodes (486 simplex iterations) in 0.06 seconds (0.08 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 5: 981950 981000 980400 ... 955175
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.819500000000e+05, best bound 9.819500000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=15
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1529 rows, 1060 columns and 11164 nonzeros
# Model fingerprint: 0x8a1e23b4
# Variable types: 0 continuous, 1060 integer (1060 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 965900.00000
# Presolve removed 677 rows and 134 columns
# Presolve time: 0.02s
# Presolved: 852 rows, 926 columns, 10302 nonzeros
# Found heuristic solution: objective 966275.00000
# Variable types: 0 continuous, 926 integer (925 binary)
#
# Root relaxation: objective 9.815000e+05, 272 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 981500.000    0   15 966275.000 981500.000  1.58%     -    0s
# H    0     0                    978450.00000 981500.000  0.31%     -    0s
# H    0     0                    981150.00000 981500.000  0.04%     -    0s
#      0     0     cutoff    0      981150.000 981150.000  0.00%     -    0s
#
# Explored 1 nodes (532 simplex iterations) in 0.05 seconds (0.07 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 4: 981150 978450 966275 965900
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.811500000000e+05, best bound 9.811500000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=16
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1737 rows, 1212 columns and 14656 nonzeros
# Model fingerprint: 0xfdf19679
# Variable types: 0 continuous, 1212 integer (1212 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 967950.00000
# Presolve removed 666 rows and 146 columns
# Presolve time: 0.03s
# Presolved: 1071 rows, 1066 columns, 13648 nonzeros
# Found heuristic solution: objective 967950.00000
# Variable types: 0 continuous, 1066 integer (1065 binary)
#
# Root relaxation: objective 9.838029e+05, 415 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 983802.941    0   15 967950.000 983802.941  1.64%     -    0s
# H    0     0                    983600.00000 983802.941  0.02%     -    0s
#      0     0     cutoff    0      983600.000 983600.000  0.00%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (734 simplex iterations) in 0.07 seconds (0.09 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 3: 983600 967950 967950
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.836000000000e+05, best bound 9.836000000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=17
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1461 rows, 1016 columns and 9752 nonzeros
# Model fingerprint: 0x7113e84a
# Variable types: 0 continuous, 1016 integer (1016 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 957200.00000
# Presolve removed 669 rows and 129 columns
# Presolve time: 0.03s
# Presolved: 792 rows, 887 columns, 8925 nonzeros
# Found heuristic solution: objective 957200.00000
# Variable types: 0 continuous, 887 integer (885 binary)
#
# Root relaxation: objective 9.751667e+05, 264 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 975166.667    0   25 957200.000 975166.667  1.88%     -    0s
# H    0     0                    972650.00000 975166.667  0.26%     -    0s
# H    0     0                    972725.00000 975166.667  0.25%     -    0s
# H    0     0                    974675.00000 974675.000  0.00%     -    0s
#      0     0          -    0      974675.000 974675.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Clique: 4
#   MIR: 1
#   Zero half: 2
#
# Explored 1 nodes (525 simplex iterations) in 0.06 seconds (0.07 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 5: 974675 972725 972650 ... 957200
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.746750000000e+05, best bound 9.746750000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=18
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M2 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1737 rows, 1204 columns and 15920 nonzeros
# Model fingerprint: 0x5a753b9c
# Variable types: 0 continuous, 1204 integer (1204 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 972800.00000
# Presolve removed 730 rows and 157 columns
# Presolve time: 0.04s
# Presolved: 1007 rows, 1047 columns, 14491 nonzeros
# Found heuristic solution: objective 972800.00000
# Variable types: 0 continuous, 1047 integer (1046 binary)
#
# Root relaxation: objective 9.826029e+05, 463 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 982602.941    0   15 972800.000 982602.941  1.01%     -    0s
# H    0     0                    981400.00000 982602.941  0.12%     -    0s
# H    0     0                    982400.00000 982602.941  0.02%     -    0s
#
# Explored 1 nodes (765 simplex iterations) in 0.08 seconds (0.11 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 4: 982400 981400 972800 972800
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.824000000000e+05, best bound 9.824000000000e+05, gap 0.0000%
# Completed: z=4, INS=500, simulation=19

# %%
### DLX+:ML
from lightgbm import LGBMClassifier

###Obtain Features of Each Problem
n_colour=4
test_rows = []
for z in [4]:#4:Realistic, 8:Random, 12:Clustered
    for INS in [500]:#Number of users
        Data=pd.read_excel('Data/User Data/Instance_'+str(z)+'.xlsx')
        data=Data.iloc[:INS].copy()
         
        for h in range(20):      
            back=DLX_v1[(DLX_v1["Instance"] == z) & (DLX_v1["User"] == INS)& (DLX_v1["Simulation"] == h)]['Backtracking percentiles idx'].values[0]
             
            beams=pd.read_csv('Data/Beam Candidate/Beams_'+str(z)+'_'+str(INS)+'_60_4_sample'+str(h)+'.csv',index_col=0)
            f = open('Data/Beam Candidate/Allocate_'+str(z)+'_'+str(INS)+'_60_4_sample'+str(h)+'.txt','r')
            allocate_data=f.read()
            f.close()
            allocate=eval(allocate_data)
            pairs_file = os.path.join('Data/Beam Candidate/', 'Pairs_'+str(z)+'_'+str(INS)+'_sample'+str(h)+'.json')
            with open(pairs_file, 'r') as f:
                pairs = json.load(f)
            
            rows_color, D_color,user_conlict,num_cons,adj,pairs,max_cliques=generate_features(beams,allocate,data,pairs)

            u=max([j for i in rows_color for j in i])
            X = extract_features_FBO(rows_color,D_color,N_max,len(beams),user_conlict,max_cliques,adj,num_cons,pairs,n_colour)
            test_rows.append({"Instance": z,"User": INS,"Simulation": h,**X,"Backtracking percentiles idx": back}) 
df_ML = pd.DataFrame(test_rows)

percentiles = [0.01, 0.05, 0.25, 0.50, 0.75, 0.95, 0.99]#Backtracking limits were selected to reflect practical operating points, ranging from minimal backtracking (1) to aggressive partial backtracking (60)
thread=10
N_max=60
DLX_ML_sol=pd.DataFrame(columns=['Instance','User','Simulation','Computation Time(s)','Total Allocated Demand','Backtracking based on percentiles'])
FEATURES = ['B', 'U', 'num_rows', 'density', 'avg_degree', 'max_degree', 'degree_std', 'D_mean', 'D_std', 'D_cv',
 'avg_row_len', 'max_row_len', 'row_density'
]
        
for z in [4]:
    for INS in [500]:
        Data=pd.read_excel('Data/User Data/Instance_'+str(z)+'.xlsx')
        data=Data.iloc[:INS].copy()
        
        for h in range(20):      
            model = LGBMClassifier(
                objective="multiclass",
                num_class=6,
                n_estimators=300,
                max_depth=6,
                learning_rate=0.05,
                subsample=0.85,
                colsample_bytree=0.85,
                min_child_samples=5,
                class_weight="balanced",
                verbose=-1          
            )

            # Create boolean mask for test
            mask_test = (
                (df_ML['Instance'] == z) &
                (df_ML['User'] == INS) &
                (df_ML['Simulation'] == h)
            )

            # Split into test and train
            df_test = df_ML.loc[mask_test].reset_index(drop=True)
            df_train = df_ML.loc[~mask_test].reset_index(drop=True)
            
            X_train = df_train[FEATURES]
            y_train = df_train["Backtracking percentiles idx"]
            model.fit(X_train, y_train)
            
             
            beams=pd.read_csv('Data/Beam Candidate/Beams_'+str(z)+'_'+str(INS)+'_60_4_sample'+str(h)+'.csv',index_col=0)
            f = open('Data/Beam Candidate/Allocate_'+str(z)+'_'+str(INS)+'_60_4_sample'+str(h)+'.txt','r')
            allocate_data=f.read()
            f.close()
            allocate=eval(allocate_data)
            pairs_file = os.path.join('Data/Beam Candidate/', 'Pairs_'+str(z)+'_'+str(INS)+'_sample'+str(h)+'.json')
            with open(pairs_file, 'r') as f:
                pairs = json.load(f)

            rows_color, orig_row, pos, D_color,u,adj,cum_demands,back=input_structure(beams,allocate,data,pairs,percentiles)

            t_start = timeit.default_timer()

            LB, greedy_sol= greedy_solution(rows_color, orig_row, pos, D_color, N_max, adj)
            
            X_test  = df_test[FEATURES]
            X_test = np.array(X_test).reshape(1, -1)
            p = model.predict(X_test)[0]/100

            target = p * LB
            back = int(np.argmin(np.abs(cum_demands - target)))+1
            best=LB

            solver = DLX(u + 1,rows_color,orig_row,D_color,LB,N_max,node)
            if best>0:
                for integer, obj in solver.search_range():
                    if obj > best:
                        best = obj
                        optimal = integer.copy()   
            t_end = timeit.default_timer()-t_start

            results = Parallel(n_jobs=10,backend="loky")(delayed(run_ML_i)(i,rows_color,D_color,orig_row,back,LB,N_max,u,t_end,best)
                               for i in range(thread))   
            max_time = max(t for t, v in results)
            best_value = max(v for t, v in results)
            DLX_ML_sol.loc[len(DLX_ML_sol)]=[z,INS,h,max_time,best_value,p]

DLX_ML_sol.to_csv('DLX_ML_results.csv')

# %%
percentiles = [0.01,0.05, 0.25, 0.50, 0.75, 0.95, 0.99]#Backtracking limits were selected to reflect practical operating points, ranging from minimal backtracking (1) to aggressive partial backtracking (60)
thread = 10# using 10 threads

DLX_LP_sol=pd.DataFrame(columns=['Instance','User','Simulation','Computation Time(s)','Total Allocated Demand','Backtracking percentiles idx'])

N_max=60
R=range(4)
for z in [4]:
    for INS in [500]:
        Data=pd.read_excel('Data/User Data/Instance_'+str(z)+'.xlsx')
        data=Data.iloc[:INS].copy()
        
        for h in range(20):        
            back=DLX_v1[(DLX_v1["Instance"] == z) & (DLX_v1["User"] == INS)& (DLX_v1["Simulation"] == h)]['Backtracking percentiles idx'].values[0]
             
            beams=pd.read_csv('Data/Beam Candidate/Beams_'+str(z)+'_'+str(INS)+'_60_4_sample'+str(h)+'.csv',index_col=0)
            f = open('Data/Beam Candidate/Allocate_'+str(z)+'_'+str(INS)+'_60_4_sample'+str(h)+'.txt','r')
            allocate_data=f.read()
            f.close()
            allocate=eval(allocate_data)
            pairs_file = os.path.join('Data/Beam Candidate/', 'Pairs_'+str(z)+'_'+str(INS)+'_sample'+str(h)+'.json')
            with open(pairs_file, 'r') as f:
                pairs = json.load(f)
            

            rows=list(allocate.values())

            B=len(beams)

            D=beams.Demand

            Q_b = {i: [] for i in data.index}
            for beam, users in allocate.items():
                for u_ in users:
                    Q_b[u_].append(beam)

            C=removeSublist(list(Q_b.values())) 

            rows=incidence_transpose_fast(C)

            adj = defaultdict(set)
            for i, j in pairs:
                adj[i].add(j)
                adj[j].add(i)            

            G = nx.Graph()
            G.add_edges_from(pairs)
            max_cliques=list(nx.find_cliques(G))

            t_start = timeit.default_timer()

            best=0
            t=0
            t1=0


            integer4_int_color,integer4_partial_color,fraction4,int_D=gurobi_LP(beams,Q_b,N_max,max_cliques,R,'C')

            if integer4_partial_color or fraction4:
                
                B_set=s = set(range(B))
                if integer4_int_color:
                    int_set = set(integer4_int_color)
                    # Step 1: collect all users served by beams in integer4
                    users_served = set().union(*(allocate[b] for b in integer4_int_color))
                    # Step 2: collect all beams serving those users
                    to_remove = int_set | set().union(*(Q_b[u] for u in users_served))
                    B_set-=to_remove

                B_set_list = list(B_set)
                D_set = np.array([D[i] for i in B_set])
                sort_index = np.argsort(-D_set)  # descending order


                top_indices = []
                median_indices = []
                rest_indices = []
                for i in sort_index:
                    idx=B_set_list[i]
                    if idx in integer4_partial_color:
                        top_indices.append(i)
                    elif idx in fraction4:
                        median_indices.append(i)
                    else:
                        rest_indices.append(i)
                    
                sort_index_reordered = top_indices+median_indices+rest_indices

                D_sort_list = D_set[sort_index_reordered].tolist()

                cum_demands = list(itertools.accumulate(D_sort_list))
                total_demands=cum_demands[-1]
                cum_demands= np.array(cum_demands)
                
                rows_sort = [allocate[B_set_list[i]] for i in sort_index_reordered]

                all_cols = sorted(set(c for row in rows_sort for c in row))
                    
                col_mapping = {old: new for new, old in enumerate(all_cols)}

                reindexed_columns = [[col_mapping[c] for c in row] for row in rows_sort]

                row_mapping = {old: new for new, old in enumerate([B_set_list[i] for i in sort_index_reordered])}


                cliques_B_set = []
                for clique in max_cliques:
                    remapped = [row_mapping[b] for b in clique if b in row_mapping]
                    if len(remapped) > 1:
                        cliques_B_set.append(remapped)
                        
                t= timeit.default_timer()-t_start

                rows_color=[]
                D_color=[]
                orig_row = []
                for idx, row in enumerate(reindexed_columns):
                    d = D_sort_list[idx]
                    for j in range(4):
                        rows_color.append(row.copy())
                        D_color.append(d) 
                        orig_row.append([idx,j])

                u = len(all_cols)+1
                for clique in cliques_B_set:
                    idxs = [j * 4 for j in clique]
                    for k in range(4):
                        for base in idxs:
                            rows_color[base + k].append(u)
                        u += 1

                t_start1 = timeit.default_timer()

                if integer4_int_color:

                    connected = defaultdict(set)

                    for p, q in pairs:
                        if p in int_set and q in B_set:
                            connected[row_mapping[q]].add(integer4_int_color[p])
                        elif q in int_set and p in B_set:
                            connected[row_mapping[p]].add(integer4_int_color[q])

                    for i in sorted(list(connected), reverse=True):
                        for j in sorted(connected[i], reverse=True):
                            idx=i*4+j
                            del rows_color[idx]
                            del orig_row[idx]
                            del D_color[idx]
                            

                back=[]

                for p in percentiles:
                    target = p * total_demands
                    node = int(np.argmin(np.abs(cum_demands - target)))
                    back.append(node*4+1)

                thread_time={p:100 for p in range(7)}
                thread_result={p:100 for p in range(7)}

                t1= t+timeit.default_timer()-t_start
                

                capacity=N_max-len(integer4_int_color)

                for run in range(3):
                    for p,node in enumerate(back):

                        best=0
  
                        t_start2 = timeit.default_timer()

                        solver = DLX(u + 1,rows_color,orig_row,D_color,0,capacity,node)

                        if node>0:
                            for integer, obj in solver.search_range():
                                if obj > best:
                                    best = obj
                                    optimal = integer.copy()
                        t2 = timeit.default_timer() - t_start2
                        D_time = t1+t2
                        if D_time<thread_time[p]:
                            thread_time[p]=D_time
                        thread_result[p] = best
                    

                results = Parallel(n_jobs=10,backend="loky")(delayed(run_single_i)(i,rows_color,D_color,orig_row,back,best,capacity,u,t1,thread_time,thread_result)
                               for i in range(10))    

                
                best_of_fastest, fastest_of_best = cumulative_analysis(thread, results, range(len(back)))
                DLX_LP_sol.loc[len(DLX_LP_sol)]=[z,INS,h,fastest_of_best["time"],fastest_of_best["value"]+int_D,fastest_of_best["p"]]


            else:
                
                best+=int_D
                t_end = timeit.default_timer()
                D_time=t_end-t_start
            
                DLX_LP_sol.loc[len(DLX_LP_sol)]=[z,INS,h,D_time,best,None]
            print(f"Completed: z={z}, INS={INS}, simulation={h}")



DLX_LP_sol.to_csv('DLX_LP_results.csv')
# Out:
# Completed: z=4, INS=500, simulation=0
# Completed: z=4, INS=500, simulation=1
# Completed: z=4, INS=500, simulation=2
# Completed: z=4, INS=500, simulation=3
# Completed: z=4, INS=500, simulation=4
# Completed: z=4, INS=500, simulation=5
# Completed: z=4, INS=500, simulation=6
# Completed: z=4, INS=500, simulation=7
# Completed: z=4, INS=500, simulation=8
# Completed: z=4, INS=500, simulation=9
# Completed: z=4, INS=500, simulation=10
# Completed: z=4, INS=500, simulation=11
# Completed: z=4, INS=500, simulation=12
# Completed: z=4, INS=500, simulation=13
# Completed: z=4, INS=500, simulation=14
# Completed: z=4, INS=500, simulation=15
# Completed: z=4, INS=500, simulation=16
# Completed: z=4, INS=500, simulation=17
# Completed: z=4, INS=500, simulation=18
# Completed: z=4, INS=500, simulation=19
